# %% [markdown]
# # Создание таблиц из json-файлов размеченных отзывов

# %%
import json
import pandas as pd

# %% [markdown]
# ## Импорт таблицы с упоминаниями лекарственных препаратов и соответствующих им стандартными названиями. Проверка корректности импорта

# %%
drugname_df = pd.read_excel('Drugname_2022.xlsx')
drugname_df
# Out:
#                               mention                         standart  \
# 0     2 в 1 garnier чистая кожа актив  garnier 2 в 1 чистая кожа актив
# 1                               5 нок                            5 нок
# 2                              5- нок                            5 нок
# 3                                5нок                            5 нок
# 4                         911 "бодяга                       911 бадяга
# ...                               ...                              ...
# 2604               vicks active sinex               vicks active sinex
# 2605                           vitrum                           vitrum
# 2606                      vitrum kids                           vitrum
# 2607                        zerosmoke                        zerosmoke
# 2608                        zolmigren                        zolmigren
#
#              ATC                                        description  \
# 0            NaN                                                NaN
# 1        J01XX07                                        Nitroxoline
# 2        J01XX07                                        Nitroxoline
# 3        J01XX07                                        Nitroxoline
# 4          D11AX      Прочие препараты для лечения заболеваний кожи
# ...          ...                                                ...
# 2604     R01AA05                                      Oxymetazoline
# 2605     A11AA04                     Поливитамины с микроэлементами
# 2606     A11AA04                     Поливитамины с микроэлементами
# 2607     N07BA03                                        Varenicline
# 2608  N02C|N02CC  Противомигренозные препараты|Селективные агони...
#
#                      comments med_NNreview                med_1kADR
# 0     Косметическое средство           NaN                   563469
# 1                         NaN      1383732                      NaN
# 2                         NaN      1383732                      NaN
# 3                         NaN      3145688                      NaN
# 4                         NaN          NaN                  2702981
# ...                       ...          ...                      ...
# 2604                      NaN          NaN                  2249637
# 2605                      NaN          NaN           1373327/671606
# 2606                      NaN          NaN                  4283315
# 2607                      NaN          NaN  1175393/1256045/1929179
# 2608  В РФ не зарегестрирован          NaN                  5765898
#
# [2609 rows x 7 columns]

# %% [markdown]
# ## Определение вспомогательных функций

# %%
def standartization(drug_list):
    standart_drug_list = [0 for i in range(len(drug_list))]
    mention, standart = list(drugname_df.mention), list(drugname_df.standart)
    for i in range(len(drug_list)):
      if drug_list[i] != 0:
          if drug_list[i].lower() in mention:
            indices = [j for j in range(0, len(mention)) if mention[j]==drug_list[i].lower()]
            for ind in indices:
              standart_drug_list[i] = standart[ind]
    return standart_drug_list


def remove_duplicates(list_with_duplicates):
    list2 = []
    for item in list_with_duplicates:
      if item not in list2:
        list2.append(item)
    return list2


def top3_drugs(ordered_list_of_drugs):
    if len(ordered_list_of_drugs) > 3:
        return ordered_list_of_drugs[:3]
    else:
        return ordered_list_of_drugs


def count_frequency(list_for_count):
    dict_with_frequency = {}
    for elem in list_for_count:
        if elem not in dict_with_frequency:
            dict_with_frequency[elem] = 0
        dict_with_frequency[elem] += 1
    return dict_with_frequency

# %% [markdown]
# ## Парсинг json-файлов:
# - cоздание для каждого упоминания лекарственного препарата количества BNE-Pos, ADE-Neg, Worse, NegatedADE, ADR и списка ADR
# - создание для каждого симптома списка лекарственных препаратов

# %%
with open("results.json", "r") as f:
    data = json.load(f)

names = []
bne_counts = []
ade_neg_counts = []
worse_counts = []
negated_ade_counts = []
adr_counts = []
adr_list = []
diseases = {}

for i in range(len(data)):
    text_id = data[i]['text_id']
    name = 'undefined'
    #for entity in data[i]['entities'].values():
    for entity in data[i]['data']['entities'].values():
        bne_count = 0
        ade_neg_count = 0
        worse_count = 0
        negated_ade_count = 0
        adr_count = 0
        adr_text = 'Нет ADR'
        if 'MedType' in entity:
            if entity["MedType"] == "Drugname":
                name = entity["text"]
                for i in range(len(names)):
                    if names[i] == 'undefined':
                        names[i] = name
        if 'DisType' in entity:
            if entity['DisType'] == "BNE-Pos":
                bne_count += 1

            if entity['DisType'] == "ADE-Neg":
                bne_count += 1

            if entity['DisType'] == 'Worse':
                worse_count += 1

            if entity['DisType'] == 'NegatedADE':
                negated_ade_count += 1

            if entity['DisType'] == 'Indication':
                adr_count += 1

            if entity['DisType'] == 'Indication' and 'MedDRA' in entity:
                adr_text = entity['MedDRA']
                key = entity['MedDRA']
                if key not in diseases:
                    diseases[key] = []
                diseases[key].append(name)

        names.append(name)
        bne_counts.append(bne_count)
        ade_neg_counts.append(ade_neg_count)
        worse_counts.append(worse_count)
        negated_ade_counts.append(negated_ade_count)
        adr_counts.append(adr_count)
        adr_list.append(adr_text)

# %%
#print(sum(adr_counts))
#count = 0
#for elem in adr_list:
#    if elem != 'Нет ADR':
#        count += 1
#print(count)

# %% [markdown]
# ## Создание таблицы препарат -- рейтинг -- список возможных ADR

# %% [markdown]
# ### Создание таблицы из списков количества сущностей BNE-Pos, ADE-Neg, Worse, NegatedADE, ADR для каждого препарата

# %%
standart_names = standartization(names)

data = {
        'standart_names':standart_names,
        'bne_counts':bne_counts,
        'ade_neg_counts':ade_neg_counts,
        'worse_counts':worse_counts,
        'negated_ade_counts':negated_ade_counts,
        'adr_counts':adr_counts
        }

df_raw = pd.DataFrame(data)
df_drugs = df_raw.groupby('standart_names').sum()

#lst_index = list(df_drugs.index)
#lst_index[0] = 'undefined'
#df_drugs.index = lst_index
df_drugs
# Out:
#                    bne_counts  ade_neg_counts  worse_counts  \
# standart_names
# 0                          40               0             0
# cold balm                   1               0             0
# evergetikon                 0               0             0
# агри                        0               0             0
# азалептин                   3               0             0
# ...                       ...             ...           ...
# эргоферон                  26               0             3
# эреспал                     0               0             0
# этиловый спирт              0               0             0
# эхинацеи настойка           1               0             0
# эхинацея                    5               0             0
#
#                    negated_ade_counts  adr_counts
# standart_names
# 0                                  10          22
# cold balm                           0           7
# evergetikon                         0           0
# агри                                5           0
# азалептин                           0           2
# ...                               ...         ...
# эргоферон                          21          34
# эреспал                             0           0
# этиловый спирт                      2           0
# эхинацеи настойка                   1           0
# эхинацея                            2           2
#
# [221 rows x 5 columns]

# %% [markdown]
# ### Добавление в таблицу количества упоминаний для каждого препарата

# %%
df_for_mentions_count = df_raw.groupby('standart_names').count()
number = df_for_mentions_count['bne_counts']
df_drugs.insert(loc=len(df_drugs.columns), column='number_of_mentions', value=number)

# %% [markdown]
# ### Добавление списка возможных ADR каждого препарата. Список возможных ADR сделан в виде словаря, где для каждого варианта ADR (в том числе для их отсутствия) посчитано количество упоминаний возникновения такого ADR у препарата

# %%
data_adr = {
        'standart_names':standart_names,
        'adr_list':adr_list
        }

df_adr = pd.DataFrame(data_adr)
df2_text = df_adr.groupby('standart_names').count()
adr_list_df = list(df2_text['adr_list'])

# %%
pointer = 0
adr_list_text = [''] * len(df2_text)
for i in range(len(df2_text)):
    pointer += adr_list_df[i]
    adr_list_text[i] = count_frequency(adr_list[pointer-adr_list_df[i]+1:pointer+1])
df_drugs.insert(loc=len(df_drugs.columns), column='adr_list_text', value=adr_list_text)

# %% [markdown]
# ### Вычисление рейтинга препаратов. Колонка neg_sum показывает сумму негативных упоминаний для препарата

# %%
df_drugs['neg_sum'] = df_drugs['ade_neg_counts'] + df_drugs['worse_counts'] + df_drugs['negated_ade_counts'] + df_drugs['adr_counts']
raiting = [''] * len(df_drugs)
for i in range(len(df_drugs)):
   if df_drugs.iloc[i]['bne_counts'] > df_drugs.iloc[i]['neg_sum']:
       if len(df_drugs.iloc[i]['adr_list_text']) > 1:
           raiting[i] = 'Хороший, но есть ADR'
       else:
           raiting[i] = 'Хороший'
   else:
       if df_drugs.iloc[i]['adr_counts'] > df_drugs.iloc[i]['negated_ade_counts'] and df_drugs.iloc[i]['adr_counts'] > df_drugs.iloc[i]['worse_counts'] and df_drugs.iloc[i]['adr_counts'] > df_drugs.iloc[i]['ade_neg_counts']:
           raiting[i] = 'Плохой: частные побочные реакции'
       elif df_drugs.iloc[i]['negated_ade_counts'] > df_drugs.iloc[i]['adr_counts'] and df_drugs.iloc[i]['negated_ade_counts'] > df_drugs.iloc[i]['worse_counts'] and df_drugs.iloc[i]['negated_ade_counts'] > df_drugs.iloc[i]['ade_neg_counts']:
           raiting[i] = 'Плохой: не помогает'
       else:
           raiting[i] = 'Плохой'
df_drugs.insert(loc=len(df_drugs.columns), column='raiting', value=raiting)

# %%
df_drugs_final = df_drugs.drop(['bne_counts', 'ade_neg_counts', 'worse_counts', 'negated_ade_counts', 'adr_counts', 'number_of_mentions', 'neg_sum'], axis=1)
df_drugs_final.columns = ['ADR', 'Raiting']
df_drugs_final
# Out:
#                                                                  ADR  \
# standart_names
# 0                  {'Нет ADR': 257, 'Стресс': 3, 'Бессонница': 1,...
# cold balm          {'Нет ADR': 26, 'Нарушение мозгового кровообра...
# evergetikon                                          {'Нет ADR': 13}
# агри                                                 {'Нет ADR': 19}
# азалептин                         {'Профилактика': 1, 'Нет ADR': 18}
# ...                                                              ...
# эргоферон          {'Нет ADR': 234, 'Боль': 1, 'Пирексия': 1, 'По...
# эреспал                                               {'Нет ADR': 1}
# этиловый спирт                                        {'Нет ADR': 4}
# эхинацеи настойка         {'Кашель': 2, 'Нет ADR': 18, 'Ринорея': 1}
# эхинацея           {'Нет ADR': 49, 'Профилактика': 1, 'Озноб': 2,...
#
#                                             Raiting
# standart_names
# 0                              Хороший, но есть ADR
# cold balm          Плохой: частные побочные реакции
# evergetikon                                  Плохой
# агри                            Плохой: не помогает
# азалептин                      Хороший, но есть ADR
# ...                                             ...
# эргоферон          Плохой: частные побочные реакции
# эреспал                                      Плохой
# этиловый спирт                  Плохой: не помогает
# эхинацеи настойка               Плохой: не помогает
# эхинацея                       Хороший, но есть ADR
#
# [221 rows x 2 columns]

# %%
df_drugs_final.to_csv('drugs_table.csv')

# %%
df_drugs_final_aggregated = df_drugs_final.groupby('Raiting').count()
df_drugs_final_aggregated.columns = ['Count']
df_drugs_final_aggregated
# Out:
#                                   Count
# Raiting
# Плохой                               44
# Плохой: не помогает                  39
# Плохой: частные побочные реакции     82
# Хороший                              16
# Хороший, но есть ADR                 40

# %%
df_drugs_final_aggregated.to_csv('drugs_table_aggregated.csv')

# %% [markdown]
# ## Создание датафрейма формата симптом -- список лучших препаратов

# %% [markdown]
# ### Создание таблицы вида симптом - список всех нестандартизироавнных названий препаратов.

# %%
data_diseases = {
    'disease':diseases.keys(),
    'drug': diseases.values()
}

df_diseases = pd.DataFrame(data_diseases)
df_diseases.set_index('disease', inplace=True)
df_diseases.head(50)
# Out:
#                                                                                     drug
# disease
# Стресс                                 [Тенотен, Валерианы экстракт, Валериана, Экстр...
# Бессонница                             [Тенотен, undefined, Сонмил, Афобазол, Афобазо...
# Нервозность                            [Тенотен, Седавит, Вечернее, Тенотен детский, ...
# Эритема глотки                         [Тонзилгон Н, Тонзилгон Н, Эргоферон, Гриппферон]
# Боль в ротоглотке (орофарингеальная)   [Тонзилгон, Тонзилгон, Тонзилгон, Граммидин Не...
# Повышенная температура тела            [АнтиГриппин, Виферон, Виферон, Виферон, Колдр...
# Нарушение речи                                                               [Кортексин]
# Нарушение засыпания                             [Мелаксен, Мелаксен, Мелаксен, Мелаксен]
# Ажитация                               [Экстракт Валерианы, Фенибут, Пустырник, корте...
# Психологическое расстройство           [Экстракт Валерианы, Аминофенилмасляная кислот...
# Ринорея                                [Виферон, Амизон, Виферон, Аква Марис, натрия ...
# Кашель                                 [Виферон, Виферон, Анаферон, Лаферобион, Лафер...
# Профилактика                           [Виферона, Ингавирин, Оксолиновая мазь, Оксоли...
# Низкое качество сна                      [Мелаксен, Сонмил, Глицин, Донормил, Феназепам]
# Почечная недостаточность                                                      [Мелаксен]
# Почечная боль                                           [Мелаксен, АнтиГриппин Максимум]
# Чихание                                [Амизон, Амизон, Амизон, Анаферон, Гриппферон,...
# Нарушение мозгового кровообращения        [Пантогам, Трентал, Трентал, Трентал, Галидор]
# Назофарингит                           [Инговерин 90, Виферон, виферон, Ацикловир Бел...
# Боль                                   [Колдрекс Хотрем, Новирин, Coldrex Maxgrip, Ре...
# Головная боль                          [Колдрекс Хотрем, валерьяна, Coldrex Maxgrip, ...
# Сухость в носу                                                     [Аква Марис, Оксолин]
# Заложенность носа                      [парацетамол, Гриппферон, Чистонос, бензоат - ...
# Першение в горле                       [парацетамол, Анвимакс, Максиколд рино, ИРС 19...
# Раздражительность                      [валерьяна, Пустырник, Пустырник, Афобазол, Аф...
# Астения                                [натрия хлорид, Сонмил, Флюколд, Анвимакс, Сон...
# Нарушение со стороны иммунной системы  [Иммунал, Лаферобион, Новирин, Ацикловир Форте...
# Психомоторная гиперактивность                                          [Тенотен детский]
# Недомогание                            [сульфадиметоксин, Coldrex, Циклоферон, Ремант...
# Папиллома                                           [Лаферобион, Лаферобион, Лаферобион]
# Сыпь                                   [Лаферобион, Димедрол, Димедрол, димедролом, А...
# CONCEPT_LESS                           [Виферон, Сомнол, ИРС 19, ИРС 19, ИРС 19, Трен...
# Пирексия                               [Coldrex Maxgrip, Coldrex Maxgrip, Новирин, Из...
# Озноб                                  [Новирин, Лимон, Ингаверин, АнтиГриппин, стопг...
# Напряженное состояние                  [Ново - Пасита, Афобазол, Глицин форте, Глицин...
# Расстройство сна                       [Фенибут, Сонмил, Сонмил, Глицин, undefined, С...
# Недостаточность марганца                                            [Кальция гопантенат]
# Зуд в губе                                                  [Ацикловир Форте, ацикловир]
# Пузырь                                 [Ацикловир Форте, Антиколд, ацикловир, ациклов...
# Струп на губе                                                          [Ацикловир Форте]
# Повышение артериального давления                [Пустырник экстракт, Барбовал, Кавинтон]
# Ощущение жара                          [Coldrex, Лаферобион, Лаферабион, нурофен, пар...
# Паническая реакция                     [Афобазол, Афобазол, афобазол, Афобазол, Афоба...
# Отечность                                                   [димедролом, Максиколд рино]
# Артралгия                                      [Афлубин, виферон, Анвимакс, АНТИГРИППИН]
# Нейропсихические симптомы                                                  [Нитроксолин]
# Поллакиурия                                                                [Нитроксолин]
# Рана                                                                       [Нитроксолин]
# Депрессия перинатального периода                                              [Афобазол]
# Тремор                                                                      [валерианка]

# %%
for value in diseases.values():
    for elem in value:
        if elem == 0:
            value.remove(elem)

for value in diseases.values():
    print(value)
    for elem in value:
        print(elem)
        if elem == 0:
            print('NULL VALUE!')
# Out:
# ['Тенотен', 'Валерианы экстракт', 'Валериана', 'Экстракт Пустырник', 'Седавит', 'Тенотен детский', 'Тенотен детский', 'Пустырник', 'Корвалола', 'Валерианы экстракт', 'валерьянка', 'валерьянку', 'валерьянка', 'валерьянку', 'Барбовал', 'Ацикловир', 'ацикловир', 'Вечернее', 'Вечернее', 'Вечернее', 'Аминофенилмасляная кислота', 'валериановые', 'валериановые', 'Персена', 'Алора', 'Афобазол', 'Афобазол', 'Афобазол', 'Глицин', 'Тенотен детский', 'Глицин', 'Афобазол', 'Корвалдин', 'Тривалумен', 'Тенотен', 'Глицин']
# Тенотен
# Валерианы экстракт
# Валериана
# Экстракт Пустырник
# Седавит
# Тенотен детский
# Тенотен детский
# Пустырник
# Корвалола
# Валерианы экстракт
# валерьянка
# валерьянку
# валерьянка
# валерьянку
# Барбовал
# Ацикловир
# ацикловир
# Вечернее
# Вечернее
# Вечернее
# Аминофенилмасляная кислота
# валериановые
# валериановые
# Персена
# Алора
# Афобазол
# Афобазол
# Афобазол
# Глицин
# Тенотен детский
# Глицин
# Афобазол
# Корвалдин
# Тривалумен
# Тенотен
# Глицин
# ['Тенотен', 'undefined', 'Сонмил', 'Афобазол', 'Афобазол', 'Афобазол', 'undefined', 'Сонмил', 'Сомнол', 'Сомнол', 'Сомнол', 'undefined', 'Реладорм', 'Глицин', 'Глицин', 'Донормил', 'Вечернее', 'Вечернее', 'Вечернее', 'Настойка пиона уклоняющегося', 'Сондокс', 'Сондокс', 'Сондокс', 'Сондокс', 'undefined', 'Мелаксен', 'undefined', 'undefined', 'Сонмил', 'Азалептин', 'Глицин', 'валерьянку', 'Афобазол', 'Афобазол', 'Тенотен детский', 'undefined', 'Сонмил', 'Сонмил', 'Тенотен', 'Глицин', 'Донормил', 'Донормил', 'Глицисед']
# Тенотен
# undefined
# Сонмил
# Афобазол
# Афобазол
# Афобазол
# undefined
# Сонмил
# Сомнол
# Сомнол
# Сомнол
# undefined
# Реладорм
# Глицин
# Глицин
# Донормил
# Вечернее
# Вечернее
# Вечернее
# Настойка пиона уклоняющегося
# Сондокс
# Сондокс
# Сондокс
# Сондокс
# undefined
# Мелаксен
# undefined
# undefined
# Сонмил
# Азалептин
# Глицин
# валерьянку
# Афобазол
# Афобазол
# Тенотен детский
# undefined
# Сонмил
# Сонмил
# Тенотен
# Глицин
# Донормил
# Донормил
# Глицисед
# ['Тенотен', 'Седавит', 'Вечернее', 'Тенотен детский', 'Афобазол', 'Мелаксен', 'валерьянку', 'Тенотен', 'Вечернее', 'Глицин', 'Трентал', 'Вечернее', 'Афобазол', 'тенотен', 'Галидор', 'Настойка валерианы', 'новопаситом', 'Персен', 'Глицин', 'глицин', 'Корвалдин', 'Корвалдин', 'фенобарбитал', 'Тривалумен', 'Тривалумен', 'Тенотен', 'Глицисед', 'Афобазол', 'Афобазол']
# Тенотен
# Седавит
# Вечернее
# Тенотен детский
# Афобазол
# Мелаксен
# валерьянку
# Тенотен
# Вечернее
# Глицин
# Трентал
# Вечернее
# Афобазол
# тенотен
# Галидор
# Настойка валерианы
# новопаситом
# Персен
# Глицин
# глицин
# Корвалдин
# Корвалдин
# фенобарбитал
# Тривалумен
# Тривалумен
# Тенотен
# Глицисед
# Афобазол
# Афобазол
# ['Тонзилгон Н', 'Тонзилгон Н', 'Эргоферон', 'Гриппферон']
# Тонзилгон Н
# Тонзилгон Н
# Эргоферон
# Гриппферон
# ['Тонзилгон', 'Тонзилгон', 'Тонзилгон', 'Граммидин Нео с анестетиком', 'Граммидин', 'Граммидин - Нео', 'виферон', 'Гриппферон', 'Граммидин Нео с анестетиком', 'Колдрекс Хотрем', 'Афлубин', 'Эвкабал', 'Циклоферон', 'Граммидин Нео с анестетиком', 'Граммидин Нео с анестетиком', 'анаферон', 'Граммидин Нео с анестетиком', 'рондо', 'Флюколд', 'АнтиГриппин', 'антигриппин', 'Граммидин Нео с анестетиком', 'стрепселсом', 'эргоферон', 'эргоферон', 'Кагоцел', 'Фенибут', 'Ингавирином', 'Гипорамин', 'Тонзилгон Н', 'Тонзилгон Н', 'АНТИГРИППИН', 'Граммидин Нео с анестетиком', 'ремантадин', 'Иммунал']
# Тонзилгон
# Тонзилгон
# Тонзилгон
# Граммидин Нео с анестетиком
# Граммидин
# Граммидин - Нео
# виферон
# Гриппферон
# Граммидин Нео с анестетиком
# Колдрекс Хотрем
# Афлубин
# Эвкабал
# Циклоферон
# Граммидин Нео с анестетиком
# Граммидин Нео с анестетиком
# анаферон
# Граммидин Нео с анестетиком
# рондо
# Флюколд
# АнтиГриппин
# антигриппин
# Граммидин Нео с анестетиком
# стрепселсом
# эргоферон
# эргоферон
# Кагоцел
# Фенибут
# Ингавирином
# Гипорамин
# Тонзилгон Н
# Тонзилгон Н
# АНТИГРИППИН
# Граммидин Нео с анестетиком
# ремантадин
# Иммунал
# ['АнтиГриппин', 'Виферон', 'Виферон', 'Виферон', 'Колдрекс Хотрем', 'анаферон', 'парацетамол', 'натрия хлорид', 'Генферон Лайт', 'Амизон', 'Виферон', 'Coldrex Maxgrip', 'Колдрекс', 'Колдрекс', 'оксолиновая', 'виферон', 'Кагоцел', 'Coldrex', 'Изопринозин', 'Изопринозин', 'Пневмо 23', 'Пневмо 23', 'Гриппферон', 'аспирин', 'гриппферон', 'ингавирин', 'ингавирин', 'Гроприносин', 'Лимон', 'Лимон', 'Лимон', 'Лимон', 'Эргофероне', 'Орвирем', 'Колдрекс Хотрем', 'ингавирин', 'Афлубин', 'Ингаверин', 'Циклоферон', 'римантогин', 'Виферон', 'Барбовал', 'Кагоцела', 'Флюколд', 'Граммидин Нео с анестетиком', 'Хелпекс', 'парацетамол', 'Эгоферон', 'эргоферон', 'парацетамол', 'парацетамол', 'Лаферабион', 'Лаферабион', 'Лаферабион', 'Антигриппин максимум', 'Антиколд', 'Эргоферон', 'парацетамолом', 'парацетамол', 'парацетамол', 'парацетамол', 'Кагоцел', 'кагоцел', 'Кагоцела', 'Анвимакс', 'Максиколд рино', 'Виферон', 'Флюколд', 'Антиколд', 'АнтиГриппин', 'антигриппин', 'Кагоцел', 'Кагоцел', 'эргоферон', 'эргоферон', 'Лавомакс', 'стопгрипан', 'стопгрипан', 'стопгрипан', 'Виферон', 'Амиксин', 'арбидола', 'Ингаверин', 'Кагоцел', 'Кагоцел', 'римантадине', 'адамантана', 'Ринза', 'Нурофеном', 'Гипорамин', 'Кипферон', 'Кипферон', 'Анафероном детским', 'Анафероном детским', 'Афлубин', 'Афлубин', 'таурин', 'Варилрикс', 'Римантадин', 'АКДС', 'Гриппол Плюс', 'Грипполом Плюс', 'АнвиМакс', 'Гриппостад', 'Афлубин', 'ирс-19', 'Виферон', 'Виферон', 'Виферон', 'Виферон', 'Кагоцел', 'Максиколд рино', 'АНТИГРИППИН', 'АНТИГРИППИН', 'АНТИГРИППИН', 'Гриппферон', 'Анаферон']
# АнтиГриппин
# Виферон
# Виферон
# Виферон
# Колдрекс Хотрем
# анаферон
# парацетамол
# натрия хлорид
# Генферон Лайт
# Амизон
# Виферон
# Coldrex Maxgrip
# Колдрекс
# Колдрекс
# оксолиновая
# виферон
# Кагоцел
# Coldrex
# Изопринозин
# Изопринозин
# Пневмо 23
# Пневмо 23
# Гриппферон
# аспирин
# гриппферон
# ингавирин
# ингавирин
# Гроприносин
# Лимон
# Лимон
# Лимон
# Лимон
# Эргофероне
# Орвирем
# Колдрекс Хотрем
# ингавирин
# Афлубин
# Ингаверин
# Циклоферон
# римантогин
# Виферон
# Барбовал
# Кагоцела
# Флюколд
# Граммидин Нео с анестетиком
# Хелпекс
# парацетамол
# Эгоферон
# эргоферон
# парацетамол
# парацетамол
# Лаферабион
# Лаферабион
# Лаферабион
# Антигриппин максимум
# Антиколд
# Эргоферон
# парацетамолом
# парацетамол
# парацетамол
# парацетамол
# Кагоцел
# кагоцел
# Кагоцела
# Анвимакс
# Максиколд рино
# Виферон
# Флюколд
# Антиколд
# АнтиГриппин
# антигриппин
# Кагоцел
# Кагоцел
# эргоферон
# эргоферон
# Лавомакс
# стопгрипан
# стопгрипан
# стопгрипан
# Виферон
# Амиксин
# арбидола
# Ингаверин
# Кагоцел
# Кагоцел
# римантадине
# адамантана
# Ринза
# Нурофеном
# Гипорамин
# Кипферон
# Кипферон
# Анафероном детским
# Анафероном детским
# Афлубин
# Афлубин
# таурин
# Варилрикс
# Римантадин
# АКДС
# Гриппол Плюс
# Грипполом Плюс
# АнвиМакс
# Гриппостад
# Афлубин
# ирс-19
# Виферон
# Виферон
# Виферон
# Виферон
# Кагоцел
# Максиколд рино
# АНТИГРИППИН
# АНТИГРИППИН
# АНТИГРИППИН
# Гриппферон
# Анаферон
# ['Кортексин']
# Кортексин
# ['Мелаксен', 'Мелаксен', 'Мелаксен', 'Мелаксен']
# Мелаксен
# Мелаксен
# Мелаксен
# Мелаксен
# ['Экстракт Валерианы', 'Фенибут', 'Пустырник', 'кортексина']
# Экстракт Валерианы
# Фенибут
# Пустырник
# кортексина
# ['Экстракт Валерианы', 'Аминофенилмасляная кислота', 'Фенибут', 'настойке пиона', 'Корвалол', 'Тенотен', 'Глицисед', 'Афобазол']
# Экстракт Валерианы
# Аминофенилмасляная кислота
# Фенибут
# настойке пиона
# Корвалол
# Тенотен
# Глицисед
# Афобазол
# ['Виферон', 'Амизон', 'Виферон', 'Аква Марис', 'натрия хлорид', 'оксолинки', 'Генферон Лайт', 'Генферон Лайт', 'Интерферон', 'Анаферона', 'сульфадимезин', 'сульфадиметоксин', 'Изопринозин', 'Виферон', 'Виферон', 'Назоферон', 'Лаферобион', 'гриппферон', 'Гриппферон', 'Назаваль - Плюс', 'анаферона', 'Изопринозин', 'Анаферон', 'Бальзам золотая звезда', 'Звёздочку', 'циклоферон', 'ингавирин', 'Аква Марис', 'Аква Марис', 'Интерферон', 'Деринат', 'кагоцел', 'Имудоном', 'Имудоном', 'Колдрекс Хотрем', 'Афлубин', 'Ингаверин', 'Виферон', 'Cold Balm', 'Флюколд', 'Хелпекс', 'Доктор Мом', 'Доктор Мом', 'изопринозин', 'Антиколд', 'Виферон', 'римантадин', 'кагоцел', 'Назаваль Плюс', 'ИРС 19', 'Эргофероном', 'Кагоцела', 'Ринофлуимуцил', 'Ринофлуимуцил', 'Анвимакс', 'Генферон лайт', 'Гриппферон', 'Амизончик', 'Флюколд', 'Аквалор Беби', 'Аквалор Беби', 'Иммунал', 'Иммунал', 'Оксолин', 'прополисом', 'отипакс', 'эргоферон', 'кагоцела', 'стопгрипан', 'Гриппферон', 'Кагоцел', 'Аквирин Рино', 'Ликопид', 'Ликопид', 'ОРВИРЕМ', 'Амизон', 'Амизон', 'Аква Марис', 'Аква Марис', 'Аква Марис', 'Аква Марис', 'Ринофлуимуцил', 'Ринофлуимуцил', 'Ингавирином', 'Виферон', 'Нурофеном', 'Аква Марис', 'Аква Марис', 'Гипорамин', 'Иммунал', 'ринофлуимуцил', 'ринофлуимуцил', 'ринофлуимуцил', 'Ксимелин', 'Ксимелин', 'Engystol', 'Энгистола', 'Генферон лайт', 'Оксолин', 'Инфагелем', 'Инфагелем', 'гропринозин', 'Ринофлуимуцил', 'Ринофлуимуцил', 'Ринофлуимуцил', 'Ринофлуимуцил', 'Гриппферон', 'Гриппферон', 'интерферон альфа-2b', 'Гриппферон', 'Гриппферон', 'анаферон детский', 'Гриппостад', 'ирс-19', 'Иммунал', 'Иммунал', 'Виферон', 'Ксимелин', 'Ксимелин', 'Ксимелин', 'Анаферон', 'Анаферон', 'Граммидин Нео с анестетиком', 'ремантадин', 'Гриппферон', 'Гриппферон', 'Интерферон', 'Ринофлуимуцил', 'Ринофлуимуцил', 'Ринофлуимуцил', 'Терафлю Экстра', 'Иммунал', 'Анаферон детский', 'Интэрферон']
# Виферон
# Амизон
# Виферон
# Аква Марис
# натрия хлорид
# оксолинки
# Генферон Лайт
# Генферон Лайт
# Интерферон
# Анаферона
# сульфадимезин
# сульфадиметоксин
# Изопринозин
# Виферон
# Виферон
# Назоферон
# Лаферобион
# гриппферон
# Гриппферон
# Назаваль - Плюс
# анаферона
# Изопринозин
# Анаферон
# Бальзам золотая звезда
# Звёздочку
# циклоферон
# ингавирин
# Аква Марис
# Аква Марис
# Интерферон
# Деринат
# кагоцел
# Имудоном
# Имудоном
# Колдрекс Хотрем
# Афлубин
# Ингаверин
# Виферон
# Cold Balm
# Флюколд
# Хелпекс
# Доктор Мом
# Доктор Мом
# изопринозин
# Антиколд
# Виферон
# римантадин
# кагоцел
# Назаваль Плюс
# ИРС 19
# Эргофероном
# Кагоцела
# Ринофлуимуцил
# Ринофлуимуцил
# Анвимакс
# Генферон лайт
# Гриппферон
# Амизончик
# Флюколд
# Аквалор Беби
# Аквалор Беби
# Иммунал
# Иммунал
# Оксолин
# прополисом
# отипакс
# эргоферон
# кагоцела
# стопгрипан
# Гриппферон
# Кагоцел
# Аквирин Рино
# Ликопид
# Ликопид
# ОРВИРЕМ
# Амизон
# Амизон
# Аква Марис
# Аква Марис
# Аква Марис
# Аква Марис
# Ринофлуимуцил
# Ринофлуимуцил
# Ингавирином
# Виферон
# Нурофеном
# Аква Марис
# Аква Марис
# Гипорамин
# Иммунал
# ринофлуимуцил
# ринофлуимуцил
# ринофлуимуцил
# Ксимелин
# Ксимелин
# Engystol
# Энгистола
# Генферон лайт
# Оксолин
# Инфагелем
# Инфагелем
# гропринозин
# Ринофлуимуцил
# Ринофлуимуцил
# Ринофлуимуцил
# Ринофлуимуцил
# Гриппферон
# Гриппферон
# интерферон альфа-2b
# Гриппферон
# Гриппферон
# анаферон детский
# Гриппостад
# ирс-19
# Иммунал
# Иммунал
# Виферон
# Ксимелин
# Ксимелин
# Ксимелин
# Анаферон
# Анаферон
# Граммидин Нео с анестетиком
# ремантадин
# Гриппферон
# Гриппферон
# Интерферон
# Ринофлуимуцил
# Ринофлуимуцил
# Ринофлуимуцил
# Терафлю Экстра
# Иммунал
# Анаферон детский
# Интэрферон
# ['Виферон', 'Виферон', 'Анаферон', 'Лаферобион', 'Лаферобион', 'виферон', 'Гриппферон', 'Изопринозин', 'Имудоном', 'Афлубин', 'Афлубин', 'Афлубин', 'амиксина', 'Эвкабал', 'Виферон', 'Флюколд', 'Антиколд', 'кагоцел', 'Эргофероном', 'Эргофероном', 'Гриппферон', 'Амизончик', 'амизон', 'амизон', 'Гриппферон', 'Флюколд', 'Иммунал', 'Иммунал', 'Кагоцел', 'Оксолин', 'эргоферон', 'эргоферон', 'эргоферон', 'Лавомакс', 'стопгрипан', 'Ингавирин', 'ОРВИРЕМ', 'Фенибут', 'Фенибут', 'фенибута', 'ринофлуимуцил', 'Тонзилгон Н', 'Engystol', 'Энгистола', 'Генферон лайт', 'Гриппферон', 'Гриппферон', 'Гриппферон', 'афлубин', 'Виферон', 'Граммидин Нео с анестетиком', 'Гриппферон', 'Эвкабал', 'Кофол', 'Кофол', 'Иммунал', 'Анаферон детский', 'Анаферон детский', 'Анаферон детский', 'Анаферон детский']
# Виферон
# Виферон
# Анаферон
# Лаферобион
# Лаферобион
# виферон
# Гриппферон
# Изопринозин
# Имудоном
# Афлубин
# Афлубин
# Афлубин
# амиксина
# Эвкабал
# Виферон
# Флюколд
# Антиколд
# кагоцел
# Эргофероном
# Эргофероном
# Гриппферон
# Амизончик
# амизон
# амизон
# Гриппферон
# Флюколд
# Иммунал
# Иммунал
# Кагоцел
# Оксолин
# эргоферон
# эргоферон
# эргоферон
# Лавомакс
# стопгрипан
# Ингавирин
# ОРВИРЕМ
# Фенибут
# Фенибут
# фенибута
# ринофлуимуцил
# Тонзилгон Н
# Engystol
# Энгистола
# Генферон лайт
# Гриппферон
# Гриппферон
# Гриппферон
# афлубин
# Виферон
# Граммидин Нео с анестетиком
# Гриппферон
# Эвкабал
# Кофол
# Кофол
# Иммунал
# Анаферон детский
# Анаферон детский
# Анаферон детский
# Анаферон детский
# ['Виферона', 'Ингавирин', 'Оксолиновая мазь', 'Оксолинкой', 'Амизон', 'Амизон', 'Амизон', 'Афлубин', 'Афлубин', 'Афлубин', 'Интерферон Альфа', 'Интерферон Альфа', 'Интерферон Альфа', 'Интерферон', 'Интерферон', 'Интерферона', 'Анаферон детский', 'Анаферон детский', 'Анаферон детский', 'Анаферона', 'Оксолин', 'Ингавирин', 'Новирин', 'Новирин', 'гриппферон', 'гриппферон', 'бензоат - натрия', 'Оксолиновая мазь', 'Гриппферон', 'Гриппферон', 'Гриппферон', 'Гриппферон', 'Гриппферон', 'ИРС19', 'ИРС19', 'анаферон', 'инозин пранобекс', 'Анаферон', 'Анаферон', 'Афлубин', 'Афлубин', 'Анаферон детский', 'циклоферона', 'Ингавирин', 'Ингавирин', 'Гриппферон', 'Гриппферон', 'Гриппферон', 'Гриппферон', 'Гриппферон', 'Гриппферон', 'Гриппферон', 'Гриппферон', 'Гриппферон', 'Гриппферон', 'Гриппферон', 'Гриппферон', 'Эргофероне', 'ИРС 19', 'Имудоном', 'Имудоном', 'Имудоном', 'ИРС 19', 'кагоцел', 'римантогин', 'римантогин', 'Граммидин', 'Граммидин', 'Иммунофлазид', 'Иммунофлазид', 'Иммунофлазид', 'анаферон', 'анаферон', 'анаферон', 'Амизон', 'Амизон', 'Эгоферон', 'оксолиновой мази', 'Арбидол', 'Арбидол', 'Иммунофлазид', 'ИРС 19', 'ИРС 19', 'Афлубин', 'Афлубин', 'Афлубин', 'Ацикловир', 'Ацикловир', 'Афлубин', 'Афлубин', 'Гриппферон', 'Афлубин', 'Афлубин', 'Афлубин', 'undefined', 'undefined', 'Глицин', 'Глицин', 'Гриппферон', 'Анаферон', 'Флавозид', 'виферон', 'интерферона', 'интерферона', 'Анаферон', 'Анаферон', 'ОКСОЛИН', 'ОКСОЛИН', 'Аквалор Беби', 'Аквалор Беби', 'Иммунал', 'Генферон Лайт', 'Генферон Лайт', 'Генферон Лайт', 'Генферон Лайт', 'Иммунофлазид', 'Ингавирин', 'Оксолина', 'Исмижен', 'Исмижен', 'Оксолин', 'Римантадин', 'Римантадин', 'Римантадин', 'Афлубин', 'Афлубин', 'Регевак В', 'Регевак В', 'Амиксин', 'Амизон', 'Амизон', 'Амизон', 'Амизон', 'Виферон', 'Амизон', 'Амизон', 'Анаферон детский', 'анаферон', 'анаферон', 'анаферон', 'ИРС 19', 'Нурофеном', 'Нурофеном', 'Виферон', 'экстракт эхинацеи', 'Энгистол', 'Энгистол', 'Афлубин', 'Афлубин', 'Оксолин', 'Оксолин', 'Афлубин', 'афлубин', 'афлубином', 'Инфагель', 'Инфагель', 'Инфагель', 'undefined', 'undefined', 'Гриппферон', 'Гриппферон', 'Иммунал', 'Иммунал', 'Иммунал', 'Иммунал', 'афлубин', 'афлубин', 'Анаферон', 'Виферон', 'Анаферон', 'Анаферон', 'Анаферон', 'Анаферон', 'Анаферон', 'Анаферон', 'Анаферон', 'Эргоферона', 'Амиксин', 'Амиксин', 'Кагоцел', 'Полижинакс', 'анаферон', 'Интерферон', 'Римантадин', 'ремантадин', 'Ингавирин', 'Ингавирин', 'undefined', 'undefined', 'Интерферон', 'Интерферон', 'Интерферон', 'Эргоферон', 'Эргоферон', 'Анаферон', 'Иммунал', 'Гриппферон', 'Гриппеферон', 'Гриппеферон', 'гриппферон', 'Иммунал', 'Инфлюцид']
# Виферона
# Ингавирин
# Оксолиновая мазь
# Оксолинкой
# Амизон
# Амизон
# Амизон
# Афлубин
# Афлубин
# Афлубин
# Интерферон Альфа
# Интерферон Альфа
# Интерферон Альфа
# Интерферон
# Интерферон
# Интерферона
# Анаферон детский
# Анаферон детский
# Анаферон детский
# Анаферона
# Оксолин
# Ингавирин
# Новирин
# Новирин
# гриппферон
# гриппферон
# бензоат - натрия
# Оксолиновая мазь
# Гриппферон
# Гриппферон
# Гриппферон
# Гриппферон
# Гриппферон
# ИРС19
# ИРС19
# анаферон
# инозин пранобекс
# Анаферон
# Анаферон
# Афлубин
# Афлубин
# Анаферон детский
# циклоферона
# Ингавирин
# Ингавирин
# Гриппферон
# Гриппферон
# Гриппферон
# Гриппферон
# Гриппферон
# Гриппферон
# Гриппферон
# Гриппферон
# Гриппферон
# Гриппферон
# Гриппферон
# Гриппферон
# Эргофероне
# ИРС 19
# Имудоном
# Имудоном
# Имудоном
# ИРС 19
# кагоцел
# римантогин
# римантогин
# Граммидин
# Граммидин
# Иммунофлазид
# Иммунофлазид
# Иммунофлазид
# анаферон
# анаферон
# анаферон
# Амизон
# Амизон
# Эгоферон
# оксолиновой мази
# Арбидол
# Арбидол
# Иммунофлазид
# ИРС 19
# ИРС 19
# Афлубин
# Афлубин
# Афлубин
# Ацикловир
# Ацикловир
# Афлубин
# Афлубин
# Гриппферон
# Афлубин
# Афлубин
# Афлубин
# undefined
# undefined
# Глицин
# Глицин
# Гриппферон
# Анаферон
# Флавозид
# виферон
# интерферона
# интерферона
# Анаферон
# Анаферон
# ОКСОЛИН
# ОКСОЛИН
# Аквалор Беби
# Аквалор Беби
# Иммунал
# Генферон Лайт
# Генферон Лайт
# Генферон Лайт
# Генферон Лайт
# Иммунофлазид
# Ингавирин
# Оксолина
# Исмижен
# Исмижен
# Оксолин
# Римантадин
# Римантадин
# Римантадин
# Афлубин
# Афлубин
# Регевак В
# Регевак В
# Амиксин
# Амизон
# Амизон
# Амизон
# Амизон
# Виферон
# Амизон
# Амизон
# Анаферон детский
# анаферон
# анаферон
# анаферон
# ИРС 19
# Нурофеном
# Нурофеном
# Виферон
# экстракт эхинацеи
# Энгистол
# Энгистол
# Афлубин
# Афлубин
# Оксолин
# Оксолин
# Афлубин
# афлубин
# афлубином
# Инфагель
# Инфагель
# Инфагель
# undefined
# undefined
# Гриппферон
# Гриппферон
# Иммунал
# Иммунал
# Иммунал
# Иммунал
# афлубин
# афлубин
# Анаферон
# Виферон
# Анаферон
# Анаферон
# Анаферон
# Анаферон
# Анаферон
# Анаферон
# Анаферон
# Эргоферона
# Амиксин
# Амиксин
# Кагоцел
# Полижинакс
# анаферон
# Интерферон
# Римантадин
# ремантадин
# Ингавирин
# Ингавирин
# undefined
# undefined
# Интерферон
# Интерферон
# Интерферон
# Эргоферон
# Эргоферон
# Анаферон
# Иммунал
# Гриппферон
# Гриппеферон
# Гриппеферон
# гриппферон
# Иммунал
# Инфлюцид
# ['Мелаксен', 'Сонмил', 'Глицин', 'Донормил', 'Феназепам']
# Мелаксен
# Сонмил
# Глицин
# Донормил
# Феназепам
# ['Мелаксен']
# Мелаксен
# ['Мелаксен', 'АнтиГриппин Максимум']
# Мелаксен
# АнтиГриппин Максимум
# ['Амизон', 'Амизон', 'Амизон', 'Анаферон', 'Гриппферон', 'Назаваль - Плюс', 'Эгоферон', 'Гриппферон', 'Амизон Макс', 'Кагоцел', 'Иммунал', 'Гриппферон', 'Анаферон', 'ремантадин']
# Амизон
# Амизон
# Амизон
# Анаферон
# Гриппферон
# Назаваль - Плюс
# Эгоферон
# Гриппферон
# Амизон Макс
# Кагоцел
# Иммунал
# Гриппферон
# Анаферон
# ремантадин
# ['Пантогам', 'Трентал', 'Трентал', 'Трентал', 'Галидор']
# Пантогам
# Трентал
# Трентал
# Трентал
# Галидор
# ['Инговерин 90', 'Виферон', 'виферон', 'Ацикловир Белупо', 'Гриппостад', 'Иммунофлазид']
# Инговерин 90
# Виферон
# виферон
# Ацикловир Белупо
# Гриппостад
# Иммунофлазид
# ['Колдрекс Хотрем', 'Новирин', 'Coldrex Maxgrip', 'Ремантадин', 'Граммидин', 'Граммидин', 'парацетамол', 'кортексин', 'Флюколд', 'Антиколд', 'Индинол Форто', 'Индинол форте', 'Амиксин', 'адамантана', 'фенибута', 'Сонмил', 'Эргоферон', 'ПОЛИЖИНАКС', 'ПОЛИЖИНАКС', 'Граммидин Нео с анестетиком', 'Граммидин нео']
# Колдрекс Хотрем
# Новирин
# Coldrex Maxgrip
# Ремантадин
# Граммидин
# Граммидин
# парацетамол
# кортексин
# Флюколд
# Антиколд
# Индинол Форто
# Индинол форте
# Амиксин
# адамантана
# фенибута
# Сонмил
# Эргоферон
# ПОЛИЖИНАКС
# ПОЛИЖИНАКС
# Граммидин Нео с анестетиком
# Граммидин нео
# ['Колдрекс Хотрем', 'валерьяна', 'Coldrex Maxgrip', 'Coldrex', 'Лимон', 'Афобазол', 'Антигриппин максимум', 'Амиксин', 'римантадин', 'Кагоцел', 'Глицин', 'Донормил', 'Максиколд рино', 'Антиколд', 'АнтиГриппин', 'Амизон Макс', 'Персена', 'эргоферон', 'Амиксин', 'арбидола', 'Глиатилин', 'кавинтоном', 'Фенибут', 'Галидор', 'Тенотен детский', 'Римантадин', 'АНТИГРИППИН']
# Колдрекс Хотрем
# валерьяна
# Coldrex Maxgrip
# Coldrex
# Лимон
# Афобазол
# Антигриппин максимум
# Амиксин
# римантадин
# Кагоцел
# Глицин
# Донормил
# Максиколд рино
# Антиколд
# АнтиГриппин
# Амизон Макс
# Персена
# эргоферон
# Амиксин
# арбидола
# Глиатилин
# кавинтоном
# Фенибут
# Галидор
# Тенотен детский
# Римантадин
# АНТИГРИППИН
# ['Аква Марис', 'Оксолин']
# Аква Марис
# Оксолин
# ['парацетамол', 'Гриппферон', 'Чистонос', 'бензоат - натрия', 'Coldrex', 'Бальзам золотая звезда', 'Аква Марис', 'Аква Марис', 'Аква Марис', 'Аквалор baby', 'Аквалор baby', 'Колдрекс Хотрем', 'Колдрекс Хотрем', 'Афлубин', 'Cold Balm', 'Cold Balm', 'Cold Balm', 'Cold Balm', 'Cold Balm', 'Золотая звезда', 'Антигриппин максимум', 'Бальзам золотая звезда', 'Гриппферон', 'Гриппферон', 'Ринофлуимуцил', 'Ринофлуимуцил', 'Амизон Макс', 'Аква Марис', 'Африн', 'Африн с эвкалиптом и ментолом', 'Африн с эвкалиптом и ментолом', 'Африн с эвкалиптом и ментолом', 'Ксимелин', 'Ринза', 'Ринза', 'АнвиМакс', 'Ксимелин', 'Ксимелин', 'АНТИГРИППИН', 'Ринофлуимуцил', 'Кофол']
# парацетамол
# Гриппферон
# Чистонос
# бензоат - натрия
# Coldrex
# Бальзам золотая звезда
# Аква Марис
# Аква Марис
# Аква Марис
# Аквалор baby
# Аквалор baby
# Колдрекс Хотрем
# Колдрекс Хотрем
# Афлубин
# Cold Balm
# Cold Balm
# Cold Balm
# Cold Balm
# Cold Balm
# Золотая звезда
# Антигриппин максимум
# Бальзам золотая звезда
# Гриппферон
# Гриппферон
# Ринофлуимуцил
# Ринофлуимуцил
# Амизон Макс
# Аква Марис
# Африн
# Африн с эвкалиптом и ментолом
# Африн с эвкалиптом и ментолом
# Африн с эвкалиптом и ментолом
# Ксимелин
# Ринза
# Ринза
# АнвиМакс
# Ксимелин
# Ксимелин
# АНТИГРИППИН
# Ринофлуимуцил
# Кофол
# ['парацетамол', 'Анвимакс', 'Максиколд рино', 'ИРС 19', 'АнвиМакс', 'Изопринозин', 'Терафлю Экстра']
# парацетамол
# Анвимакс
# Максиколд рино
# ИРС 19
# АнвиМакс
# Изопринозин
# Терафлю Экстра
# ['валерьяна', 'Пустырник', 'Пустырник', 'Афобазол', 'Афобазол', 'глицин', 'Седасен форте', 'Глицин', 'Глицин', 'Барбовал', 'Донормил', 'Вечернее', 'Глицин', 'Глицин', 'Глицин', 'Афобазол', 'новопаситом', 'Депприм', 'Тенотен', 'Глицисед', 'Афобазол']
# валерьяна
# Пустырник
# Пустырник
# Афобазол
# Афобазол
# глицин
# Седасен форте
# Глицин
# Глицин
# Барбовал
# Донормил
# Вечернее
# Глицин
# Глицин
# Глицин
# Афобазол
# новопаситом
# Депприм
# Тенотен
# Глицисед
# Афобазол
# ['натрия хлорид', 'Сонмил', 'Флюколд', 'Анвимакс', 'Сондокс', 'Селанк', 'Сонмил', 'Иммунала', 'Вечернее', 'Ринза', 'АнвиМакс']
# натрия хлорид
# Сонмил
# Флюколд
# Анвимакс
# Сондокс
# Селанк
# Сонмил
# Иммунала
# Вечернее
# Ринза
# АнвиМакс
# ['Иммунал', 'Лаферобион', 'Новирин', 'Ацикловир Форте', 'Галавит', 'Антигриппин максимум', 'Ацикловир', 'Гроприносин', 'Ацик', 'Иммунал', 'Оксолин', 'интерферона']
# Иммунал
# Лаферобион
# Новирин
# Ацикловир Форте
# Галавит
# Антигриппин максимум
# Ацикловир
# Гроприносин
# Ацик
# Иммунал
# Оксолин
# интерферона
# ['Тенотен детский']
# Тенотен детский
# ['сульфадиметоксин', 'Coldrex', 'Циклоферон', 'Ремантадин', 'Ангрикапс Максима']
# сульфадиметоксин
# Coldrex
# Циклоферон
# Ремантадин
# Ангрикапс Максима
# ['Лаферобион', 'Лаферобион', 'Лаферобион']
# Лаферобион
# Лаферобион
# Лаферобион
# ['Лаферобион', 'Димедрол', 'Димедрол', 'димедролом', 'Ацикловир', 'ацикловир', 'Окавакс', 'Окавакс', 'докозанол', 'докозанол', 'ацикловир']
# Лаферобион
# Димедрол
# Димедрол
# димедролом
# Ацикловир
# ацикловир
# Окавакс
# Окавакс
# докозанол
# докозанол
# ацикловир
# ['Виферон', 'Сомнол', 'ИРС 19', 'ИРС 19', 'ИРС 19', 'Трентал', 'Трентал', 'Трентал', 'Трентал', 'Трентал', 'ацикловира']
# Виферон
# Сомнол
# ИРС 19
# ИРС 19
# ИРС 19
# Трентал
# Трентал
# Трентал
# Трентал
# Трентал
# ацикловира
# ['Coldrex Maxgrip', 'Coldrex Maxgrip', 'Новирин', 'Изопринозин', 'арбидол', 'Амиксин', 'Эргоферон', 'Гриппферон', 'Ангрикапс Максима', 'АнтиГриппин', 'Эргоферон', 'эргоферон', 'эргоферон', 'эргоферон', 'Виферон', 'Ингавирин', 'арбидола', 'Ингавирин', 'Ринза', 'Ринза', 'LinkusСимптоматическая терапия Орви', 'LinkusСимптоматическая терапия Орви', 'Виферон', 'Нурофен', 'Генферон лайт', 'Гриппол Плюс', 'Афлубин', 'Кагоцел', 'Гриппферон', 'Анаферон детский']
# Coldrex Maxgrip
# Coldrex Maxgrip
# Новирин
# Изопринозин
# арбидол
# Амиксин
# Эргоферон
# Гриппферон
# Ангрикапс Максима
# АнтиГриппин
# Эргоферон
# эргоферон
# эргоферон
# эргоферон
# Виферон
# Ингавирин
# арбидола
# Ингавирин
# Ринза
# Ринза
# LinkusСимптоматическая терапия Орви
# LinkusСимптоматическая терапия Орви
# Виферон
# Нурофен
# Генферон лайт
# Гриппол Плюс
# Афлубин
# Кагоцел
# Гриппферон
# Анаферон детский
# ['Новирин', 'Лимон', 'Ингаверин', 'АнтиГриппин', 'стопгрипан', 'Кагоцел', 'АНТИГРИППИН', 'АНТИГРИППИН', 'ремантадин', 'Афобазол', 'афобазола']
# Новирин
# Лимон
# Ингаверин
# АнтиГриппин
# стопгрипан
# Кагоцел
# АНТИГРИППИН
# АНТИГРИППИН
# ремантадин
# Афобазол
# афобазола
# ['Ново - Пасита', 'Афобазол', 'Глицин форте', 'Глицин форте', 'Донормил', 'Глицин', 'Глицин', 'Корвалол']
# Ново - Пасита
# Афобазол
# Глицин форте
# Глицин форте
# Донормил
# Глицин
# Глицин
# Корвалол
# ['Фенибут', 'Сонмил', 'Сонмил', 'Глицин', 'undefined', 'Сомнол', 'Глицин']
# Фенибут
# Сонмил
# Сонмил
# Глицин
# undefined
# Сомнол
# Глицин
# ['Кальция гопантенат']
# Кальция гопантенат
# ['Ацикловир Форте', 'ацикловир']
# Ацикловир Форте
# ацикловир
# ['Ацикловир Форте', 'Антиколд', 'ацикловир', 'ацикловир', 'Ацикловир', 'ацикловир']
# Ацикловир Форте
# Антиколд
# ацикловир
# ацикловир
# Ацикловир
# ацикловир
# ['Ацикловир Форте']
# Ацикловир Форте
# ['Пустырник экстракт', 'Барбовал', 'Кавинтон']
# Пустырник экстракт
# Барбовал
# Кавинтон
# ['Coldrex', 'Лаферобион', 'Лаферабион', 'нурофен', 'парацетамол']
# Coldrex
# Лаферобион
# Лаферабион
# нурофен
# парацетамол
# ['Афобазол', 'Афобазол', 'афобазол', 'Афобазол', 'Афобазол', 'Афобазол', 'Корвалол', 'корвалдин', 'Глицисед', 'корвалола']
# Афобазол
# Афобазол
# афобазол
# Афобазол
# Афобазол
# Афобазол
# Корвалол
# корвалдин
# Глицисед
# корвалола
# ['димедролом', 'Максиколд рино']
# димедролом
# Максиколд рино
# ['Афлубин', 'виферон', 'Анвимакс', 'АНТИГРИППИН']
# Афлубин
# виферон
# Анвимакс
# АНТИГРИППИН
# ['Нитроксолин']
# Нитроксолин
# ['Нитроксолин']
# Нитроксолин
# ['Нитроксолин']
# Нитроксолин
# ['Афобазол']
# Афобазол
# ['валерианка']
# валерианка
# ['Лимон', 'Кагоцел', 'Терафлю Экстра']
# Лимон
# Кагоцел
# Терафлю Экстра
# ['Кортексин']
# Кортексин
# ['Кортексин']
# Кортексин
# ['Кортексин']
# Кортексин
# ['Кортексин', 'Кортексин']
# Кортексин
# Кортексин
# ['Эхинацеи', 'Эхинацеи']
# Эхинацеи
# Эхинацеи
# ['Граммидин Нео с анестетиком', 'акдс', 'Полижинакс']
# Граммидин Нео с анестетиком
# акдс
# Полижинакс
# ['энцефабол']
# энцефабол
# ['глицин', 'Кортексин']
# глицин
# Кортексин
# ['Панавир', 'панавиром']
# Панавир
# панавиром
# ['Панавир', 'Виферон']
# Панавир
# Виферон
# ['Панавир']
# Панавир
# ['Панавир', 'отипакс', 'Кофол']
# Панавир
# отипакс
# Кофол
# ['Эвкабал', 'Эвкабал бальзам']
# Эвкабал
# Эвкабал бальзам
# ['Сонмил']
# Сонмил
# ['Сонмил', 'Селанк', 'Селанк', 'Фенилэфрин']
# Сонмил
# Селанк
# Селанк
# Фенилэфрин
# ['Мелаксен', 'мелаксен']
# Мелаксен
# мелаксен
# ['Мелаксен', 'Coldrex', 'Фенилэфрин']
# Мелаксен
# Coldrex
# Фенилэфрин
# ['Мелаксен']
# Мелаксен
# ['Cold Balm', 'Гриппферон', 'Ринофлуимуцил']
# Cold Balm
# Гриппферон
# Ринофлуимуцил
# ['валерьянку', 'Корвалол']
# валерьянку
# Корвалол
# ['Барбовал', 'Ликопид', 'Тенотен детский']
# Барбовал
# Ликопид
# Тенотен детский
# ['Ремантадин']
# Ремантадин
# ['Граммидин Нео с анестетиком', 'Максиколд рино', 'Флюколд', 'стопгрипан', 'стопгрипан', 'ремантадин']
# Граммидин Нео с анестетиком
# Максиколд рино
# Флюколд
# стопгрипан
# стопгрипан
# ремантадин
# ['фенибут', 'Барбовал', 'Афобазол', 'Афобазол', 'Афобазол', 'Афобазол', 'Афобазол', 'Афобазол', 'Корвалол', 'Корвалол', 'корвалола', 'корвалола', 'корвалола']
# фенибут
# Барбовал
# Афобазол
# Афобазол
# Афобазол
# Афобазол
# Афобазол
# Афобазол
# Корвалол
# Корвалол
# корвалола
# корвалола
# корвалола
# ['Нитроксолин', 'Нитроксолин']
# Нитроксолин
# Нитроксолин
# ['Глицин']
# Глицин
# ['Глицин']
# Глицин
# ['Глицин']
# Глицин
# ['Ацикловир']
# Ацикловир
# ['Ацикловир', 'Ацикловир', 'Ацикловир', 'Герперакс', 'Ацик', 'Ацик', 'ацикловира', 'Ацикловир Белупо']
# Ацикловир
# Ацикловир
# Ацикловир
# Герперакс
# Ацик
# Ацик
# ацикловира
# Ацикловир Белупо
# ['Пантогам']
# Пантогам
# ['Пирацетамом', 'фенибут', 'Трентал']
# Пирацетамом
# фенибут
# Трентал
# ['изопринозин', 'Граммидин Нео с анестетиком', 'стопгрипан']
# изопринозин
# Граммидин Нео с анестетиком
# стопгрипан
# ['Амиксин', 'Амиксин', 'Корвалол']
# Амиксин
# Амиксин
# Корвалол
# ['Ацикловир']
# Ацикловир
# ['ацикловир', 'Окавакс', 'Полижинакс']
# ацикловир
# Окавакс
# Полижинакс
# ['undefined']
# undefined
# ['кортексин']
# кортексин
# ['Ацикловир']
# Ацикловир
# ['Эргофероном']
# Эргофероном
# ['Глицин']
# Глицин
# ['Донормил']
# Донормил
# ['фенибут']
# фенибут
# ['Гриппферон', 'ПОЛИЖИНАКС', 'ПОЛИЖИНАКС', 'ПОЛИЖИНАКС', 'ПОЛИЖИНАКС', 'Кипферон', 'Кипферон']
# Гриппферон
# ПОЛИЖИНАКС
# ПОЛИЖИНАКС
# ПОЛИЖИНАКС
# ПОЛИЖИНАКС
# Кипферон
# Кипферон
# ['фенистилом', 'фенистилом', 'Ациком', 'Ацикловир Белупо', 'Ацикловир']
# фенистилом
# фенистилом
# Ациком
# Ацикловир Белупо
# Ацикловир
# ['фенистилом', 'ацикловир', 'стрепселсом', 'Ацикловир']
# фенистилом
# ацикловир
# стрепселсом
# Ацикловир
# ['Сондокс', 'Сонмил']
# Сондокс
# Сонмил
# ['Трентал']
# Трентал
# ['Трентал']
# Трентал
# ['Трентал']
# Трентал
# ['Трентал']
# Трентал
# ['Трентал']
# Трентал
# ['Луцетам', 'Луцетам', 'Луцетам', 'циннаризин', 'Корвалол', 'Пирацетам', 'Пирацетама', 'Пирацетама']
# Луцетам
# Луцетам
# Луцетам
# циннаризин
# Корвалол
# Пирацетам
# Пирацетама
# Пирацетама
# ['АнтиГриппин']
# АнтиГриппин
# ['Вечернего']
# Вечернего
# ['стрепселсом']
# стрепселсом
# ['отипакс']
# отипакс
# ['Кавинтон форте']
# Кавинтон форте
# ['Кавинтон форте']
# Кавинтон форте
# ['Кавинтон форте']
# Кавинтон форте
# ['ПОЛИЖИНАКС']
# ПОЛИЖИНАКС
# ['ПОЛИЖИНАКС']
# ПОЛИЖИНАКС
# ['ПОЛИЖИНАКС']
# ПОЛИЖИНАКС
# ['ПОЛИЖИНАКС']
# ПОЛИЖИНАКС
# ['Ингавирин']
# Ингавирин
# ['парацетомол', 'Галидор', 'Эргоферон', 'Аквалором', 'Аквалором']
# парацетомол
# Галидор
# Эргоферон
# Аквалором
# Аквалором
# ['арбидола']
# арбидола
# ['Ликопид']
# Ликопид
# ['Ликопид']
# Ликопид
# ['Ингавирин', 'Ингавирин']
# Ингавирин
# Ингавирин
# ['Глиатилин', 'кавинтоном', 'Пирацетам', 'Пирацетама', 'Пирацетама']
# Глиатилин
# кавинтоном
# Пирацетам
# Пирацетама
# Пирацетама
# ['ОРВИРЕМ']
# ОРВИРЕМ
# ['Регевак В', 'Виферон']
# Регевак В
# Виферон
# ['Амазоном']
# Амазоном
# ['Ринофлуимуцил']
# Ринофлуимуцил
# ['Ринофлуимуцил']
# Ринофлуимуцил
# ['Ингавирином']
# Ингавирином
# ['АнвиМакса']
# АнвиМакса
# ['Галидор']
# Галидор
# ['Галидор']
# Галидор
# ['Галидор']
# Галидор
# ['Глицин']
# Глицин
# ['Сонмил']
# Сонмил
# ['Эргоферон']
# Эргоферон
# ['Эргоферон']
# Эргоферон
# ['Персен']
# Персен
# ['Персен']
# Персен
# ['Фенилэфрин']
# Фенилэфрин
# ['Фенилэфрин']
# Фенилэфрин
# ['Пирацетам']
# Пирацетам
# ['Пирацетам']
# Пирацетам
# ['Ацикловир', 'ацикловир']
# Ацикловир
# ацикловир
# ['Ацикловир']
# Ацикловир
# ['Ацикловир']
# Ацикловир
# ['Генферон', 'Генферон', 'Генферон']
# Генферон
# Генферон
# Генферон
# ['акдс']
# акдс
# ['Азалептин']
# Азалептин
# ['Глицин', 'Тенотен детский', 'Тенотен детский', 'Тенотен детский', 'Глиатилин', 'Глиатилин']
# Глицин
# Тенотен детский
# Тенотен детский
# Тенотен детский
# Глиатилин
# Глиатилин
# ['Афобазол']
# Афобазол
# ['Полижинакс']
# Полижинакс
# ['ПОЛИЖИНАКС', 'ПОЛИЖИНАКС']
# ПОЛИЖИНАКС
# ПОЛИЖИНАКС
# ['ПОЛИЖИНАКС']
# ПОЛИЖИНАКС
# ['Полижинакс']
# Полижинакс
# ['Сонмил']
# Сонмил
# ['Сонмил', 'Глицисед']
# Сонмил
# Глицисед
# ['Глицин']
# Глицин
# ['Донормил']
# Донормил
# ['Эргоферон']
# Эргоферон
# ['Корвалол']
# Корвалол

# %%
diseases.values()
# Out:
# dict_values([['Тенотен', 'Валерианы экстракт', 'Валериана', 'Экстракт Пустырник', 'Седавит', 'Тенотен детский', 'Тенотен детский', 'Пустырник', 'Корвалола', 'Валерианы экстракт', 'валерьянка', 'валерьянку', 'валерьянка', 'валерьянку', 'Барбовал', 'Ацикловир', 'ацикловир', 'Вечернее', 'Вечернее', 'Вечернее', 'Аминофенилмасляная кислота', 'валериановые', 'валериановые', 'Персена', 'Алора', 'Афобазол', 'Афобазол', 'Афобазол', 'Глицин', 'Тенотен детский', 'Глицин', 'Афобазол', 'Корвалдин', 'Тривалумен', 'Тенотен', 'Глицин'], ['Тенотен', 'undefined', 'Сонмил', 'Афобазол', 'Афобазол', 'Афобазол', 'undefined', 'Сонмил', 'Сомнол', 'Сомнол', 'Сомнол', 'undefined', 'Реладорм', 'Глицин', 'Глицин', 'Донормил', 'Вечернее', 'Вечернее', 'Вечернее', 'Настойка пиона уклоняющегося', 'Сондокс', 'Сондокс', 'Сондокс', 'Сондокс', 'undefined', 'Мелаксен', 'undefined', 'undefined', 'Сонмил', 'Азалептин', 'Глицин', 'валерьянку', 'Афобазол', 'Афобазол', 'Тенотен детский', 'undefined', 'Сонмил', 'Сонмил', 'Тенотен', 'Глицин', 'Донормил', 'Донормил', 'Глицисед'], ['Тенотен', 'Седавит', 'Вечернее', 'Тенотен детский', 'Афобазол', 'Мелаксен', 'валерьянку', 'Тенотен', 'Вечернее', 'Глицин', 'Трентал', 'Вечернее', 'Афобазол', 'тенотен', 'Галидор', 'Настойка валерианы', 'новопаситом', 'Персен', 'Глицин', 'глицин', 'Корвалдин', 'Корвалдин', 'фенобарбитал', 'Тривалумен', 'Тривалумен', 'Тенотен', 'Глицисед', 'Афобазол', 'Афобазол'], ['Тонзилгон Н', 'Тонзилгон Н', 'Эргоферон', 'Гриппферон'], ['Тонзилгон', 'Тонзилгон', 'Тонзилгон', 'Граммидин Нео с анестетиком', 'Граммидин', 'Граммидин - Нео', 'виферон', 'Гриппферон', 'Граммидин Нео с анестетиком', 'Колдрекс Хотрем', 'Афлубин', 'Эвкабал', 'Циклоферон', 'Граммидин Нео с анестетиком', 'Граммидин Нео с анестетиком', 'анаферон', 'Граммидин Нео с анестетиком', 'рондо', 'Флюколд', 'АнтиГриппин', 'антигриппин', 'Граммидин Нео с анестетиком', 'стрепселсом', 'эргоферон', 'эргоферон', 'Кагоцел', 'Фенибут', 'Ингавирином', 'Гипорамин', 'Тонзилгон Н', 'Тонзилгон Н', 'АНТИГРИППИН', 'Граммидин Нео с анестетиком', 'ремантадин', 'Иммунал'], ['АнтиГриппин', 'Виферон', 'Виферон', 'Виферон', 'Колдрекс Хотрем', 'анаферон', 'парацетамол', 'натрия хлорид', 'Генферон Лайт', 'Амизон', 'Виферон', 'Coldrex Maxgrip', 'Колдрекс', 'Колдрекс', 'оксолиновая', 'виферон', 'Кагоцел', 'Coldrex', 'Изопринозин', 'Изопринозин', 'Пневмо 23', 'Пневмо 23', 'Гриппферон', 'аспирин', 'гриппферон', 'ингавирин', 'ингавирин', 'Гроприносин', 'Лимон', 'Лимон', 'Лимон', 'Лимон', 'Эргофероне', 'Орвирем', 'Колдрекс Хотрем', 'ингавирин', 'Афлубин', 'Ингаверин', 'Циклоферон', 'римантогин', 'Виферон', 'Барбовал', 'Кагоцела', 'Флюколд', 'Граммидин Нео с анестетиком', 'Хелпекс', 'парацетамол', 'Эгоферон', 'эргоферон', 'парацетамол', 'парацетамол', 'Лаферабион', 'Лаферабион', 'Лаферабион', 'Антигриппин максимум', 'Антиколд', 'Эргоферон', 'парацетамолом', 'парацетамол', 'парацетамол', 'парацетамол', 'Кагоцел', 'кагоцел', 'Кагоцела', 'Анвимакс', 'Максиколд рино', 'Виферон', 'Флюколд', 'Антиколд', 'АнтиГриппин', 'антигриппин', 'Кагоцел', 'Кагоцел', 'эргоферон', 'эргоферон', 'Лавомакс', 'стопгрипан', 'стопгрипан', 'стопгрипан', 'Виферон', 'Амиксин', 'арбидола', 'Ингаверин', 'Кагоцел', 'Кагоцел', 'римантадине', 'адамантана', 'Ринза', 'Нурофеном', 'Гипорамин', 'Кипферон', 'Кипферон', 'Анафероном детским', 'Анафероном детским', 'Афлубин', 'Афлубин', 'таурин', 'Варилрикс', 'Римантадин', 'АКДС', 'Гриппол Плюс', 'Грипполом Плюс', 'АнвиМакс', 'Гриппостад', 'Афлубин', 'ирс-19', 'Виферон', 'Виферон', 'Виферон', 'Виферон', 'Кагоцел', 'Максиколд рино', 'АНТИГРИППИН', 'АНТИГРИППИН', 'АНТИГРИППИН', 'Гриппферон', 'Анаферон'], ['Кортексин'], ['Мелаксен', 'Мелаксен', 'Мелаксен', 'Мелаксен'], ['Экстракт Валерианы', 'Фенибут', 'Пустырник', 'кортексина'], ['Экстракт Валерианы', 'Аминофенилмасляная кислота', 'Фенибут', 'настойке пиона', 'Корвалол', 'Тенотен', 'Глицисед', 'Афобазол'], ['Виферон', 'Амизон', 'Виферон', 'Аква Марис', 'натрия хлорид', 'оксолинки', 'Генферон Лайт', 'Генферон Лайт', 'Инт ...

# %% [markdown]
# ### Далее преобразование данных - стандартизация названий препаратов, отбор препаратов только с хорошим рейтингом, сортировка по количеству упоминаний препарата, отбор максимум трех лучших.

# %%
def only_good_raiting(list_of_drugs):
    new_list_of_drugs = []
    for drug in list_of_drugs:
        if drug == 0:
            continue
        if df_drugs.loc[drug]['raiting'] in ['Хороший','Хороший, но есть ADR']:
            new_list_of_drugs.append(drug)
    return new_list_of_drugs

def sort_drugs_on_review_number(list_of_drugs):
    dict_of_drugs = {}
    sorted_list = []
    for drug in list_of_drugs:
        dict_of_drugs[drug] = df_drugs.loc[drug]['number_of_mentions']
    sorted_tuples = sorted(dict_of_drugs.items(), key=lambda item: item[1])
    for i in range(len(sorted_tuples)):
        sorted_list.append(sorted_tuples[i][0])
    return sorted_list[::-1]


for key, value in diseases.items():
    diseases[key] = standartization(value)
    diseases[key] = remove_duplicates(diseases[key])
    diseases[key] = only_good_raiting(diseases[key])
    diseases[key] = sort_drugs_on_review_number(diseases[key])
    diseases[key] = top3_drugs(diseases[key])
    if diseases[key] == []:
        diseases[key] = 'Нет хороших лекарств'
    if diseases[key] != 'Нет хороших лекарств':
        diseases[key] = ', '.join(diseases[key])

# %%
data_diseases = {
    'disease':diseases.keys(),
    'drug': diseases.values()
}

df_diseases_final = pd.DataFrame(data_diseases)
df_diseases_final.head(50)
# Out:
#                                   disease  \
# 0                                  Стресс
# 1                              Бессонница
# 2                             Нервозность
# 3                          Эритема глотки
# 4    Боль в ротоглотке (орофарингеальная)
# 5             Повышенная температура тела
# 6                          Нарушение речи
# 7                     Нарушение засыпания
# 8                                Ажитация
# 9            Психологическое расстройство
# 10                                Ринорея
# 11                                 Кашель
# 12                           Профилактика
# 13                    Низкое качество сна
# 14               Почечная недостаточность
# 15                          Почечная боль
# 16                                Чихание
# 17     Нарушение мозгового кровообращения
# 18                           Назофарингит
# 19                                   Боль
# 20                          Головная боль
# 21                         Сухость в носу
# 22                      Заложенность носа
# 23                       Першение в горле
# 24                      Раздражительность
# 25                                Астения
# 26  Нарушение со стороны иммунной системы
# 27          Психомоторная гиперактивность
# 28                            Недомогание
# 29                              Папиллома
# 30                                   Сыпь
# 31                           CONCEPT_LESS
# 32                               Пирексия
# 33                                  Озноб
# 34                  Напряженное состояние
# 35                       Расстройство сна
# 36               Недостаточность марганца
# 37                             Зуд в губе
# 38                                 Пузырь
# 39                          Струп на губе
# 40       Повышение артериального давления
# 41                          Ощущение жара
# 42                     Паническая реакция
# 43                              Отечность
# 44                              Артралгия
# 45              Нейропсихические симптомы
# 46                            Поллакиурия
# 47                                   Рана
# 48       Депрессия перинатального периода
# 49                                 Тремор
#
#                                             drug
# 0                             персен, тривалумен
# 1                            глицисед, азалептин
# 2                   глицисед, персен, тривалумен
# 3                                    тонзилгон н
# 4                  флюколд, тонзилгон н, эвкабал
# 5                   лаферобион, флюколд, орвирем
# 6                           Нет хороших лекарств
# 7                           Нет хороших лекарств
# 8                           Нет хороших лекарств
# 9                                       глицисед
# 10               интерферон, лаферобион, орвирем
# 11                  лаферобион, орвирем, флюколд
# 12        интерферон, иммунофлазид, аквалор беби
# 13                                     феназепам
# 14                          Нет хороших лекарств
# 15                          антигриппин максимум
# 16                          Нет хороших лекарств
# 17                          Нет хороших лекарств
# 18                                  иммунофлазид
# 19                   флюколд, колдрекс максгрипп
# 20          колдрекс, персен, колдрекс максгрипп
# 21                          Нет хороших лекарств
# 22         колдрекс, ринза, антигриппин максимум
# 23                       терафлю, максиколд рино
# 24                       глицисед, седасен форте
# 25                        флюколд, ринза, селанк
# 26  интерферон, лаферобион, антигриппин максимум
# 27                          Нет хороших лекарств
# 28                                      колдрекс
# 29                                    лаферобион
# 30                          лаферобион, димедрол
# 31                          Нет хороших лекарств
# 32                     ринза, колдрекс максгрипп
# 33                          Нет хороших лекарств
# 34                          Нет хороших лекарств
# 35                          Нет хороших лекарств
# 36                            кальция гопантенат
# 37                          Нет хороших лекарств
# 38                          Нет хороших лекарств
# 39                          Нет хороших лекарств
# 40                          Нет хороших лекарств
# 41                          лаферобион, колдрекс
# 42                                      глицисед
# 43                      максиколд рино, димедрол
# 44                          Нет хороших лекарств
# 45                          Нет хороших лекарств
# 46                          Нет хороших лекарств
# 47                          Нет хороших лекарств
# 48                          Нет хороших лекарств
# 49                          Нет хороших лекарств

# %%
df_diseases_final.to_csv('diseases_table.csv')
